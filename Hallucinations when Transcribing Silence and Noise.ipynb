# %%
pip install krixik
# Out:
# Requirement already satisfied: krixik in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (1.1.17)
# Requirement already satisfied: boto3 in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from krixik) (1.34.39)
# Requirement already satisfied: nltk in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from krixik) (3.8.1)
# Requirement already satisfied: numpy in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from krixik) (1.26.1)
# Requirement already satisfied: pillow in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from krixik) (10.2.0)
# Requirement already satisfied: pyaml in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from krixik) (23.12.0)
# Requirement already satisfied: pypdf in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from krixik) (3.17.1)
# Requirement already satisfied: pytest in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from krixik) (7.4.3)
# Requirement already satisfied: pytest-subtests in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from krixik) (0.11.0)
# Requirement already satisfied: python-docx in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from krixik) (1.1.0)
# Requirement already satisfied: python-dotenv in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from krixik) (1.0.0)
# Requirement already satisfied: python-pptx in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from krixik) (0.6.23)
# Requirement already satisfied: requests in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from krixik) (2.31.0)
# Requirement already satisfied: botocore<1.35.0,>=1.34.39 in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from boto3->krixik) (1.34.52)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from boto3->krixik) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from boto3->krixik) (0.10.0)
# Requirement already satisfied: click in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from nltk->krixik) (8.1.7)
# Requirement already satisfied: joblib in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from nltk->krixik) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from nltk->krixik) (2023.12.25)
# Requirement already satisfied: tqdm in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from nltk->krixik) (4.66.1)
# Requirement already satisfied: PyYAML in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from pyaml->krixik) (6.0.1)
# Requirement already satisfied: iniconfig in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from pytest->krixik) (2.0.0)
# Requirement already satisfied: packaging in c:\users\lucas\appdata\roaming\python\python312\site-packages (from pytest->krixik) (23.2)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from pytest->krixik) (1.3.0)
# Requirement already satisfied: colorama in c:\users\lucas\appdata\roaming\python\python312\site-packages (from pytest->krixik) (0.4.6)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from pytest-subtests->krixik) (23.2.0)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from python-docx->krixik) (4.9.3)
# Requirement already satisfied: typing-extensions in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from python-docx->krixik) (4.8.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from python-pptx->krixik) (3.1.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from requests->krixik) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from requests->krixik) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from requests->krixik) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lucas\appdata\local\programs\python\python312\lib\site-packages (from requests->krixik) (2023.7.22)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\lucas\appdata\roaming\python\python312\site-packages (from botocore<1.35.0,>=1.34.39->boto3->krixik) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\lucas\appdata\roaming\python\python312\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.39->boto3->krixik) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys 
sys.path.append('..')
from dotenv import load_dotenv
import os
load_dotenv()

LUCAS_STAGING_API_KEY=os.getenv('LUCAS_STAGING_API_KEY')
LUCAS_STAGING_API_URL=os.getenv('LUCAS_STAGING_API_URL')

# import Krixik
from krixik import krixik
krixik.init(api_key = LUCAS_STAGING_API_KEY, 
            api_url = LUCAS_STAGING_API_URL)

import json
def json_print(data):
    print(json.dumps(data, indent=2))

# %load_ext autoreload
# %autoreload 2
# Out:
# SUCCESS: You are now authenticated.

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Hallucinations when Transcribing Silence and Noise
#
# Certain types of AI models take non-text input and generate a textual interpretation of this input. They don't extract existing text (as [OCR](https://krixik-docs.readthedocs.io/en/latest/modules/ai_modules/ocr_module/) does) or search through text (like [semantic search](https://krixik-docs.readthedocs.io/en/latest/system/search_methods/semantic_search_method/)), but generate the text outright. Two fine examples are [transcription](https://krixik-docs.readthedocs.io/en/latest/modules/ai_modules/transcribe_module/) models, which receive an audio input and output a textual transcript of any spoken words within the audio, and [image captioning](https://krixik-docs.readthedocs.io/en/latest/modules/ai_modules/caption_module/) models, which generate a textual description of an input image file.
#
# In this article we explore the hallucinations transcription models produce when their input is devoid of processable content (click here[LINK] for an article in which we perform a similar exercise for image captioning models). Transcription is a complex task, and models struggle when presented with little or nothing to generate a textual interpretation of. The extreme version of this is entirely silent audio, but audio with noise/music and no clear spoken voice proves just as challenging a task.
#
# To see what this looks like in practice, we'll use [Krixik](https://krixik-docs.readthedocs.io/en/latest/) to build a [single-module](https://krixik-docs.readthedocs.io/en/latest/examples/single_module_pipelines/single_transcribe/) pipeline with a [transcribe](https://krixik-docs.readthedocs.io/en/latest/modules/ai_modules/transcribe_module/) module:

# %%
# instantiate a single-module pipeline with a transcribe module
pipeline_1 = krixik.create_pipeline(name='my_transcribe_pipeline',
                                    module_chain=['transcribe'])

# %% [markdown]
# ### Hallucinations when Transcribing Silence
#
# Our file, *silence.mp3*, is a completely silent audio. Let's see what happens when we [.process](https://krixik-docs.readthedocs.io/en/latest/system/parameters_processing_files_through_pipelines/process_method/) it through our pipeline while leveraging three different [available models](https://krixik-docs.readthedocs.io/en/latest/modules/ai_modules/transcribe_module/#available-models-in-the-transcribe-module), which upon random selection are:
#
# - [whisper-medium](https://huggingface.co/openai/whisper-medium)
# - [whisper-small](https://huggingface.co/openai/whisper-small)
# - [whisper-base](https://huggingface.co/openai/whisper-base)
#
# [whisper-medium](https://huggingface.co/openai/whisper-medium), the strongest of these three, will go first:

# %%
# .process a silent audio through the transcribe module with whisper-medium as the active model
pipeline_1.process(local_file_path='./test_files/silence.mp3',
                   modules={'transcribe': {'model': 'whisper-medium', 'params': {}}})
# Out:
# INFO: hydrated input modules: {'module_1': {'model': 'whisper-medium', 'params': {}}}
# INFO: symbolic_directory_path was not set by user - setting to default of /etc
# INFO: file_name was not set by user - setting to random file name: krixik_generated_file_name_zbwodqyniy.mp3
# INFO: expire_time was not set by user - setting to default of 1800 seconds
# INFO: wait_for_process is set to True.
# INFO: file will expire and be removed from you account in 1800 seconds, at Sat Jun  1 00:04:17 2024 UTC
# INFO: my_transcribe_pipeline file process and input processing started...
# INFO: metadata can be updated using the .update api.
# INFO: This process's request_id is: 77258e5a-19c8-8978-051f-d28fa6b5928c
# INFO: File process and processing status:
# SUCCESS: module 1 (of 1) - module_1 processing complete.
# SUCCESS: pipeline process complete.
# SUCCESS: process output downloaded.
# {'status_code': 200,
#  'pipeline': 'my_transcribe_pipeline',
#  'request_id': '45d40379-3175-40e8-b54e-d36d0ff08951',
#  'file_id': '31b668d4-32c1-42d2-939f-089a1e28e771',
#  'message': 'SUCCESS - output fetched for file_id 31b668d4-32c1-42d2-939f-089a1e28e771.Output saved to location(s) listed in process_output_files.',
#  'warnings': [],
#  'process_output': [{'transcript': ' you',
#    'timestamped_transcript': [{'id': 0,
#      'start': 0.0,
#      'end': 0.82,
#      'text': ' you',
#      'no_speech_prob': 0.934208869934082,
#      'confidence': 0.29,
#      'words': [{'text': 'you',
#        'start': 0.0,
#        'end': 0.82,
#        'confidence': 0.29}]}]}],
#  'process_output_files': ['c:\\Users\\Lucas\\Desktop\\Content/31b668d4-32c1-42d2-939f-089a1e28e771.json']}

# %% [markdown]
# As you can see, despite the audio being completely silent, the model detects the word "you" in its first second.
#
# Now [whisper-small](https://huggingface.co/openai/whisper-small), a less powerful member of the Whisper family:

# %%
# .process a silent audio through the transcribe module with whisper-small as the active model
pipeline_1.process(local_file_path='./test_files/silence.mp3',
                   modules={'transcribe': {'model': 'whisper-small', 'params': {}}})
# Out:
# INFO: hydrated input modules: {'module_1': {'model': 'whisper-small', 'params': {}}}
# INFO: symbolic_directory_path was not set by user - setting to default of /etc
# INFO: file_name was not set by user - setting to random file name: krixik_generated_file_name_tymepxopnh.mp3
# INFO: expire_time was not set by user - setting to default of 1800 seconds
# INFO: wait_for_process is set to True.
# INFO: file will expire and be removed from you account in 1800 seconds, at Sat Jun  1 00:07:50 2024 UTC
# INFO: my_transcribe_pipeline file process and input processing started...
# INFO: metadata can be updated using the .update api.
# INFO: This process's request_id is: 80a06ebf-bb3b-0591-362d-b48d77d85fae
# INFO: File process and processing status:
# SUCCESS: module 1 (of 1) - module_1 processing complete.
# SUCCESS: pipeline process complete.
# SUCCESS: process output downloaded.
# {'status_code': 200,
#  'pipeline': 'my_transcribe_pipeline',
#  'request_id': '34dac7c6-252e-4467-b6e3-ad0a5bfc22ed',
#  'file_id': '2d0c214e-1be0-45ce-af29-ac80732b0a40',
#  'message': 'SUCCESS - output fetched for file_id 2d0c214e-1be0-45ce-af29-ac80732b0a40.Output saved to location(s) listed in process_output_files.',
#  'warnings': [],
#  'process_output': [{'transcript': ' you',
#    'timestamped_transcript': [{'id': 0,
#      'start': 0.18,
#      'end': 1.1,
#      'text': ' you',
#      'no_speech_prob': 0.9380698204040527,
#      'confidence': 0.234,
#      'words': [{'text': 'you',
#        'start': 0.18,
#        'end': 1.1,
#        'confidence': 0.234}]}]}],
#  'process_output_files': ['c:\\Users\\Lucas\\Desktop\\Content/2d0c214e-1be0-45ce-af29-ac80732b0a40.json']}

# %% [markdown]
# Both models have detected the word "you" in roughly the same place, though note that the timestamps differ a bit. [whisper-medium](https://huggingface.co/openai/whisper-medium) detects it from 0.0 to 0.82, while [whisper-small](https://huggingface.co/openai/whisper-small) detects it from 0.18 to 1.1. Once again, bear in mind that there is no sound of any type in this audio.
#
# What about [whisper-base](https://huggingface.co/openai/whisper-base), the smallest of these three?

# %%
# .process a silent audio through the transcribe module with whisper-base as the active model
pipeline_1.process(local_file_path='./test_files/silence.mp3',
                   modules={'transcribe': {'model': 'whisper-base', 'params': {}}})
# Out:
# INFO: hydrated input modules: {'module_1': {'model': 'whisper-base', 'params': {}}}
# INFO: symbolic_directory_path was not set by user - setting to default of /etc
# INFO: file_name was not set by user - setting to random file name: krixik_generated_file_name_utxagxjchl.mp3
# INFO: expire_time was not set by user - setting to default of 1800 seconds
# INFO: wait_for_process is set to True.
# INFO: file will expire and be removed from you account in 1800 seconds, at Sat Jun  1 00:11:02 2024 UTC
# INFO: my_transcribe_pipeline file process and input processing started...
# INFO: metadata can be updated using the .update api.
# INFO: This process's request_id is: 7326d3f8-e7d7-6163-f1f4-5c4185253467
# INFO: File process and processing status:
# SUCCESS: module 1 (of 1) - module_1 processing complete.
# SUCCESS: pipeline process complete.
# SUCCESS: process output downloaded.
# {'status_code': 200,
#  'pipeline': 'my_transcribe_pipeline',
#  'request_id': '640434e0-1b85-4077-8c60-e9e289bba5f1',
#  'file_id': 'a728067e-4d4d-4113-9c2c-c640df855e26',
#  'message': 'SUCCESS - output fetched for file_id a728067e-4d4d-4113-9c2c-c640df855e26.Output saved to location(s) listed in process_output_files.',
#  'warnings': [],
#  'process_output': [{'transcript': ' you',
#    'timestamped_transcript': [{'id': 0,
#      'start': 2.48,
#      'end': 2.5,
#      'text': ' you',
#      'no_speech_prob': 0.9320588707923889,
#      'confidence': 0.247,
#      'words': [{'text': 'you',
#        'start': 2.48,
#        'end': 2.5,
#        'confidence': 0.247}]}]}],
#  'process_output_files': ['c:\\Users\\Lucas\\Desktop\\Content/a728067e-4d4d-4113-9c2c-c640df855e26.json']}

# %% [markdown]
# Fascinating. This smallest model also detects the word "you", but long after the other two do: not in the first second of the audio, but in the third!
#
# ### Hallucinations when Transcribing Noise
#
# Now let's try an audio file in which there are only modem sounds. Those of you 25 years or older may remember these well. We'll use new random selection of three [available models](https://krixik-docs.readthedocs.io/en/latest/modules/ai_modules/transcribe_module/#available-models-in-the-transcribe-module):
#
# - [whisper-tiny](https://huggingface.co/openai/whisper-tiny), the module's default model
# - [whisper-medium](https://huggingface.co/openai/whisper-medium)
# - [whisper-base](https://huggingface.co/openai/whisper-base)
#
# [whisper-tiny](https://huggingface.co/openai/whisper-tiny) goes first. Since it's the module's [default model](https://krixik-docs.readthedocs.io/en/latest/modules/ai_modules/transcribe_module/#available-models-in-the-transcribe-module), we don't have to specify it:

# %%
# .process a modem-sounds audio through the transcribe module without specifying the model, since whisper-tiny is default
pipeline_1.process(local_file_path='./test_files/modem_sounds.mp3')
# Out:
# INFO: hydrated input modules: {'module_1': {'model': 'whisper-tiny', 'params': {}}}
# INFO: symbolic_directory_path was not set by user - setting to default of /etc
# INFO: file_name was not set by user - setting to random file name: krixik_generated_file_name_efyjfaauqr.mp3
# INFO: expire_time was not set by user - setting to default of 1800 seconds
# INFO: wait_for_process is set to True.
# INFO: file will expire and be removed from you account in 1800 seconds, at Sat Jun  1 00:20:05 2024 UTC
# INFO: my_transcribe_pipeline file process and input processing started...
# INFO: metadata can be updated using the .update api.
# INFO: This process's request_id is: 59b5a63d-403a-4ba5-1255-ca1909fa5284
# INFO: File process and processing status:
# SUCCESS: module 1 (of 1) - module_1 processing complete.
# SUCCESS: pipeline process complete.
# SUCCESS: process output downloaded.
# {'status_code': 200,
#  'pipeline': 'my_transcribe_pipeline',
#  'request_id': '3438d535-b799-48ba-9445-15611c425eb6',
#  'file_id': 'f26060b4-b318-4ec6-b98f-539b45044abb',
#  'message': 'SUCCESS - output fetched for file_id f26060b4-b318-4ec6-b98f-539b45044abb.Output saved to location(s) listed in process_output_files.',
#  'warnings': [],
#  'process_output': [{'transcript': " I'm not sure if you can see the sound of the sound of the sound of the sound. I'm not sure if you can see the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of",
#    'timestamped_transcript': [{'id': 0,
#      'start': 60.0,
#      'end': 63.16,
#      'text': " I'm not sure if you can see the sound of the sound of the sound of the sound.",
#      'no_speech_prob': 0.6730110049247742,
#      'confidence': 0.187,
#      'words': [{'text': "I'm",
#        'start': 60.0,
#        'end': 60.8,
#        'confidence': 0.089},
#       {'text': 'not', 'start': 60.8, 'end': 60.82, 'confidence': 0.104},
#       {'text': 'sure', 'start': 60.82, 'end': 61.52, 'confidence': 0.18},
#       {'text': 'if', 'start': 61.52, 'end': 61.54, 'confidence': 0.302},
#       {'text': 'you', 'start': 61.54, 'end': 61.56, 'confidence': 0.251},
#       {'text': 'can', 'start': 61.56, 'end': 61.58, 'confidence': 0.273},
#       {'text': 'see', 'start': 61.58, 'end': 61.6, 'confidence': 0.121},
#       {'text': 'the', 'start': 61.6, 'end': 61.62, 'confidence': 0.183},
#       {'text': 'sound', 'start': 61.62, 'end': 61.64, 'confidence': 0.02},
#       {'text': 'of', 'start': 61.64, 'end': 61.66, 'confidence': 0.426},
#       {'text': 'the', 'start': 61.66, 'end': 61.68, 'confidence': 0.349},
#       {'text': 'sound', 'start': 61.68, 'end': 61.7, 'confidence': 0.118},
#       {'text': 'of', 'start': 61.7, 'end': 61.72, 'confidence': 0.274},
#       {'text': 'the', 'start': 61.72, 'end': 61.74, 'confidence': 0.427},
#       {'text': 'sound', 'start': 61.74, 'end': 61.76, 'confidence': 0.165},
#       {'text': 'of', 'start': 61.76, 'end': 61.78, 'confidence': 0.189},
#       {'text': 'the', 'start': 61.78, 'end': 61.8, 'confidence': 0.55},
#       {'text': 'sound.', 'start': 61.8, 'end': 63.16, 'confidence': 0.327}]},
#     {'id': 1,
#      'start': 65.0,
#      'end': 94.98,
#      'text': " I'm not sure if you can see the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound",
#      'no_speech_prob': 0.5722651481628418,
#      'confidence': 0.936,
#      'words': [{'text': "I'm",
#        'start': 65.0,
#        'end': 66.68,
#        'confidence': 0.196},
#       {'text': 'not', 'start': 66.68, 'end': 66.82, 'confidence': 0.547},
#       {'text': 'sure', 'start': 66.82, 'end': 66.84, 'confidence': 0.983},
#       {'text': 'if', 'start': 66.84, 'end': 66.86, 'confidence': 0.723},
#       {'text': 'you', 'start': 66.86, 'end': 66.88, 'confidence': 0.762},
#       {'text': 'can', 'start': 66.88, 'end': 68.76, 'confidence': 0.852},
#       {'text': 'see', 'start': 68.76, 'end': 68.78, 'confidence': 0.796},
#       {'text': 'the', 'start': 68.78, 'end': 68.8, 'confidence': 0.776},
#       {'text': 'sound', 'start': 68.8, 'end': 68.82, 'confidence': 0.94},
#       {'text': 'of', 'start': 68.82, 'end': 68.92, 'confidence': 0.897},
#       {'text': 'the', 'start': 68.92, 'end': 68.94, 'confidence': 0.933},
#       {'text': 'sound', 'start': 68.94, 'end': 68.96, 'confidence': 0.957},
#       {'text': 'of', 'start': 68.96, 'end': 68.98, 'confidence': 0.711},
#       {'text': 'the', 'start': 68.98, 'end': 69.06, 'confidence': 0.922},
#       {'text': 'sound', 'start': 69.06, 'end': 69.08, 'confidence': 0.96},
#       {'text': 'of', 'start': 69.08, 'end': 70.02, 'confidence': 0.62},
#       {'text': 'the', 'start': 70.02, 'end': 71.36, 'confidence': 0.912},
#       {'text': 'sound', 'start': 71.36, 'end': 71.86, 'confidence': 0.964},
#       {'text': 'of', 'start': 71.86, 'end': 71.96, 'confidence': 0.645},
#       {'text': 'the', 'start': 71.96, 'end': 72.48, 'confidence': 0.914},
#       {'text': 'sound', 'start': 72.48, 'end': 72.5, 'confidence': 0.968},
#       {'text': 'of', 'start': 72.5, 'end': 72.64, 'confidence': 0.697},
#       {'text': 'the', 'start': 72.64, 'end': 73.2, 'confidence': 0.923},
#       {'text': 'sound', 'start': 73.2, 'end': 73.22, 'confidence': 0.971},
#       {'text': 'of', 'start': 73.22, 'end': 73.24, 'confidence': 0.726},
#       {'text': 'the', 'start': 73.24, 'end': 73.76, 'confidence': 0.929},
#       {'text': 'sound', 'start': 73.76, 'end': 73.8, 'confidence': 0.972},
#       {'text': 'of', 'start': 73.8, 'end': 73.82, 'confidence': 0.794},
#       {'text': 'the', 'start': 73.82, 'end': 75.78, 'confidence': 0.932},
#       {'text': 'sound', 'start': 75.78, 'end': 75.8, 'confidence': 0.972},
#       {'text': 'of', 'start': 75.8, 'end': 76.0, 'confidence': 0.842},
#       {'text': 'the', 'start': 76.0, 'end': 76.04, 'confidence': 0.934},
#       {'text': 'sound', 'start': 76.04, 'end': 76.06, 'confidence': 0.971},
#       {'text': 'of', 'start': 76.06, 'end': 76.12, 'confidence': 0.862},
#       {'text': 'the', 'start': 76.12, 'end': 76.14, 'confidence': 0.936},
#       {'text': 'sound', 'start': 76.14, 'end': 76.16, 'confidence': 0.97},
#       {'text': 'of', 'start': 76.16, 'end': 77.0, 'confidence': 0.878},
#       {'text': 'the', 'start': 77.0, 'end': 77.02, 'confidence': 0.939},
#       {'text': 'sound', 'start': 77.02, 'end': 77.04, 'confidence': 0.969},
#       {'text': 'of', 'start': 77.04, 'end': 77.06, 'confidence': 0.891},
#       {'text': 'the', 'start': 77.06, 'end': 77.08, 'confidence': 0.944},
#       {'text': 'sound', 'start': 77.08, 'end': 77.1, 'confidence': 0.971},
#       {'text': 'of', 'start': 77.1, 'end': 77.12, 'confidence': 0.907},
#       {'text': 'the', 'start': 77.12, 'end': 77.14, 'confidence': 0.948},
#       {'text': 'sound', 'start': 77.14, 'end': 77.16, 'confidence': 0.971},
#       {'text': 'of', 'start': 77.16, 'end': 77.72, 'confidence': 0.918},
#       {'text': 'the', 'start': 77.72, 'end': 77.74, 'confidence': 0.956},
#       {'text': 'sound', 'start': 77.74, 'end': 77.76, 'confidence': 0.973},
#       {'text': 'of', 'start': 77.76, 'end': 77.78, 'confidence': 0.925},
#       {'text': 'the', 'start': 77.78, 'end': 77.8, 'confidence': 0.961},
#       {'text': 'sound', 'start': 77.8, 'end': 77.82, 'confidence': 0.973},
#       {'text': 'of', 'start': 77.82, 'end': 78.26, 'confidence': 0.931},
#       {'text': 'the', 'start': 78.26, 'end': 78.28, 'confidence': 0.961},
#       {'text': 'sound', 'start': 78.28, 'end': 78.3, 'confidence': 0.973},
#       {'text': 'of', 'start': 78.3, 'end': 78.5, 'confidence': 0.937},
#       {'text': 'the', 'start': 78.5, 'end': 78.52, 'confidence': 0.967},
#       {'text': 'sound', 'start': 78.52, 'end': 78.54, 'confidence': 0.974},
#       {'text': 'of', 'start': 78.54, 'end': 78.72, 'confidence': 0.938},
#       {'text': 'the', 'start': 78.72, 'end': 78.74, 'confidence': 0.967},
#       {'text': 'sound', 'start': 78.74, 'end': 79.04, 'confidence': 0.974},
#       {'text': 'of', 'start': 79.04, 'end': 79.06, 'confidence': 0.939},
#       {'text': 'the', 'start': 79.06, 'end': 80.08, 'confidence': 0.965},
#       {'text': 'sound', 'start': 80.08, 'end': 80.1, 'confidence': 0.973},
#       {'text': 'of', 'start': 80.1, 'end': 80.18, 'confidence': 0.944},
#       {'text': 'the', 'start': 80.18, 'end': 80.7, 'confidence': 0.966},
#       {'text': 'sound', 'start': 80.7, 'end': 80.72, 'confidence': 0.974},
#       {'text': 'of', 'start': 80.72, 'end': 80.74, 'confidence': 0.945},
#       {'text': 'the', 'start': 80.74, 'end': 80.76, 'confidence': 0.964},
#       {'text': 'sound', 'start': 80.76, 'end': 80.78, 'confidence': 0.973},
#       {'text': 'of', 'start': 80.78, 'end': 80.8, 'confidence': 0.952},
#       {'text': 'the', 'start': 80.8, 'end': 80.82, 'confidence': 0.968},
#       {'text': 'sound', 'start': 80.82, 'end': 80.84, 'confidence': 0.974},
#       {'text': 'of', 'start': 80.84, 'end': 80.86, 'confidence': 0.954},
#       {'text': 'the', 'start': 80.86, 'end': 80.88, 'confidence': 0.967},
#       {'text': 'sound', 'start': 80.88, 'end': 80.9, 'confidence': 0.974},
#       {'text': 'of', 'start': 80.9, 'end': 80.92, 'confidence': 0.958},
#       {'text': 'the', 'start': 80.92, 'end': 80.94, 'confidence': 0.968},
#       {'text': 'sound', 'start': 80.94, 'end': 80.96, 'confidence': 0.974},
#       {'text': 'of', 'start': 80.96, 'end': 80.98, 'confidence': 0.96},
#       {'text': 'the', 'start': 80.98, 'end': 81.0, 'confidence': 0.969},
#       {'text': 'sound', 'start': 81.0, 'end': 81.02, 'confidence': 0.974},
#       {'text': 'of', 'start': 81.02, 'end': 81.04, 'confidence': 0.961},
#       {'text': 'the', 'start': 81.04, 'end': 81.06, 'confidence': 0.968},
#       {'text': 'sound', 'start': 81.06, 'end': 81.08, 'confidence': 0.974},
#       {'text': 'of', 'start': 81.08, 'end': 81.1, 'confidence': 0.963},
#       {'text': 'the', 'start': 81.1, 'end': 81.12, 'confidence': 0.968},
#       {'text': 'sound', 'start': 81.12, 'end': 81.14, 'confidence': 0.974},
#       {'text': 'of', 'start': 81.14, 'end': 81.16, 'confidence': 0.964},
#       {'text': 'the', 'start': 81.16, 'end': 81.18, 'confidence': 0.969},
#       {'text': 'sound', 'start': 81.18, 'end': 81.2, 'confidence': 0.975},
#       {'text': 'of', 'start': 81.2, 'end': 81.68, 'confidence': 0.962},
#       {'text': 'the', 'start': 81.68, 'end': 81.7, 'confidence': 0.969},
#       {'text': 'sound', 'start': 81.7, 'end': 81.72, 'confidence': 0.975},
#       {'text': 'of', 'start': 81.72, 'end': 81.74, 'confidence': 0.965},
#       {'text': 'the', 'start': 81.74, 'end': 81.76, 'confidence': 0.97},
#       {'text': 'sound', 'start': 81.76, 'end': 81.78, 'confidence': 0.975},
#       {'text': 'of', 'start': 81.78, 'end': 81.8, 'confidence': 0.966},
#       {'text': 'the', 'start': 81.8, 'end': 81.82, 'confidence': 0.972},
#       {'text': 'sound', 'start': 81.82, 'end': 81.84, 'confidence': 0.975},
#       {'text': 'of', 'start': 81.84, 'end': 81.86, 'confidence': 0.966},
#       {'text': 'the', 'start': 81.86, 'end': 81.88, 'confidence': 0.973},
#       {'text': 'sound', 'start': 81.88, 'end': 81.9, 'confidence': 0.976},
#       {'text': 'of', 'start': 81.9, 'end': 81.92, 'confidence': 0.967},
#       {'text': 'the', 'start': 81.92, 'end': 81.94, 'confidence': 0.974},
#       {'text': 'sound', 'start': 81.94, 'end': 81.96, 'confidence': 0.976},
#       {'text': 'of', 'start': 81.96, 'end': 81.98, 'confidence': 0.968},
#       {'text': 'the', 'start': 81.98, 'end': 82.0, 'confidence': 0.974},
#       {'text': 'sound', 'start': 82.0, 'end': 82.02, 'confidence': 0.975},
#       {'text': 'of', 'start': 82.02, 'end': 82.04, 'confidence': 0.967},
#       {'text': 'the', 'start': 82.04, 'end': 82.06, 'confidence': 0.973},
#       {'text': 'sound', 'start': 82.06, 'end': 82.08, 'confidence': 0.975},
#       {'text': 'of', 'start': 82.08, 'end': 82.1, 'confidence': 0.97},
#       {'text': 'the', 'start': 82.1, 'end': 82.12, 'confidence': 0.97},
#       {'text': 'sound', 'start': 82.12, 'end': 82.14, 'confidence': 0.975},
#       {'text': 'of', 'start': 82.14, 'end': 82.16, 'confidence': 0.97},
#       {'text': 'the', 'start': 82.16, 'end': 82.18, 'confidence': 0.971},
#       {'text': 'sound', 'start': 82.18, 'end': 82.2, 'confidence': 0.974},
#       {'text': 'of', 'start': 82.2, 'end': 82.22, 'confidence': 0.972},
#       {'text': 'the', 'start': 82.22, 'end': 82.24, 'confidence': 0.97},
#       {'text': 'sound', 'start': 82.24, 'end': 82.3, 'confidence': 0.972},
#       {'text': 'of', 'start': 82.3, 'end': 82.32, 'confidence': 0.972},
#       {'text': 'the', 'start': 82.32, 'end': 82.34, 'confidence': 0.97},
#       {'text': 'sound', 'start': 82.34, 'end': 82.36, 'confidence': 0.973},
#       {'text': 'of', 'start': 82.36, 'end': 82.38, 'confidence': 0.975},
#       {'text': 'the', 'start': 82.38, 'end': 82.4, 'confidence': 0.97},
#       {'text': 'sound', 'start': 82.4, 'end': 82.42, 'confidence': 0.973},
#       {'text': 'of', 'start': 82.42, 'end': 82.44, 'confidence': 0.975},
#       {'text': 'the', 'start': 82.44, 'end': 82.46, 'confidence': 0.972},
#       {'text': 'sound', 'start': 82.46, 'end': 82.48, 'confidence': 0.974},
#       {'text': 'of', 'start': 82.48, 'end': 82.5, 'confidence': 0.976},
#       {'text': 'the', 'start': 82.5, 'end': 82.52, 'confidence': 0.971},
#       {'text': 'sound', 'start': 82.52, 'end': 82.54, 'confidence': 0.974},
#       {'text': 'of', 'start': 82.54, 'end': 82.56, 'confidence': 0.975},
#       {'text': 'the', 'start': 82.56, 'end': 82.58, 'confidence': 0.973},
#       {'text': 'sound', 'start': 82.58, 'end': 82.6, 'confidence': 0.973},
#       {'text': 'of', 'start': 82.6, 'end': 82.62, 'confidence': 0.977},
#       {'text': 'the', 'start': 82.62, 'end': 82.64, 'confidence': 0.973},
#       {'text': 'sound', 'start': 82.64, 'end': 82.66, 'confidence': 0.974},
#       {'text': 'of', 'start': 82.66, 'end': 82.68, 'confidence': 0.976},
#       {'text': 'the', 'start': 82.68, 'end': 82.7, 'confidence': 0.972},
#       {'text': 'sound', 'start': 82.7, 'end': 82.72, 'confidence': 0.973},
#       {'text': 'of', 'start': 82.72, 'end': 82.74, 'confidence': 0.976},
#       {'text': 'the', 'start': 82.74, 'end': 82.76, 'confidence': 0.972},
#       {'text': 'sound', 'start': 82.76, 'end': 82.78, 'confidence': 0.974},
#       {'text': 'of', 'start': 82.78, 'end': 82.8, 'confidence': 0.977},
#       {'text': 'the', 'start': 82.8, 'end': 82.82, 'confidence': 0.973},
#       {'text': 'sound', 'start': 82.82, 'end': 82.84, 'confidence': 0.973},
#       {'text': 'of', 'start': 82.84, 'end': 82.86, 'confidence': 0.979},
#       {'text': 'the', 'start': 82.86, 'end': 82.88, 'confidence': 0.973},
#       {'text': 'sound', 'start': 82.88, 'end': 82.9, 'confidence': 0.974},
#       {'text': 'of', 'start': 82.9, 'end': 82.92, 'confidence': 0.978},
#       {'text': 'the', 'start': 82.92, 'end': 82.94, 'confidence': 0.974},
#       {'text': 'sound', 'start': 82.94, 'end': 82.96, 'confidence': 0.973},
#       {'text': 'of', 'start': 82.96, 'end': 82.98, 'confidence': 0.979},
#       {'text': 'the', 'start': 82.98, 'end': 83.0, 'confidence': 0.973},
#       {'text': 'sound', 'start': 83.0, 'end': 83.02, 'confidence': 0.973},
#       {'text': 'of', 'start': 83.02, 'end': 83.04, 'confidence': 0.979},
#       {'text': 'the', 'start': 83.04, 'end': 83.06, 'confidence': 0.972},
#       {'text': 'sound', 'start': 83.06, 'end': 83.08, 'confidence': 0.972},
#       {'text': 'of', 'start': 83.08, 'end': 83.1, 'confidence': 0.978},
#       {'text': 'the', 'start': 83.1, 'end': 83.12, 'confidence': 0.972},
#       {'text': 'sound', 'start': 83.12, 'end': 83.14, 'confidence': 0.972},
#       {'text': 'of', 'start': 83.14, 'end': 83.16, 'confidence': 0.978},
#       {'text': 'the', 'start': 83.16, 'end': 83.18, 'confidence': 0.972},
#       {'text': 'sound', 'start': 83.18, 'end': 83.2, 'confidence': 0.971},
#       {'text': 'of', 'start': 83.2, 'end': 83.22, 'confidence': 0.979},
#       {'text': 'the', 'start': 83.22, 'end': 83.24, 'confidence': 0.97},
#       {'text': 'sound', 'start': 83.24, 'end': 83.26, 'confidence': 0.971},
#       {'text': 'of', 'start': 83.26, 'end': 83.28, 'confidence': 0.982},
#       {'text': 'the', 'start': 83.28, 'end': 83.3, 'confidence': 0.972},
#       {'text': 'sound', 'start': 83.3, 'end': 83.32, 'confidence': 0.971},
#       {'text': 'of', 'start': 83.32, 'end': 83.34, 'confidence': 0.98},
#       {'text': 'the', 'start': 83.34, 'end': 83.36, 'confidence': 0.972},
#       {'text': 'sound', 'start': 83.36, 'end': 83.38, 'confidence': 0.972},
#       {'text': 'of', 'start': 83.38, 'end': 83.4, 'confidence': 0.981},
#       {'text': 'the', 'start': 83.4, 'end': 83.42, 'confidence': 0.972},
#       {'text': 'sound', 'start': 83.42, 'end': 83.44, 'confidence': 0.971},
#       {'text': 'of', 'start': 83.44, 'end': 83.46, 'confidence': 0.981},
#       {'text': 'the', 'start': 83.46, 'end': 83.48, 'confidence': 0.972},
#       {'text': 'sound', 'start': 83.48, 'end': 83.5, 'confidence': 0.972},
#       {'text': 'of', 'start': 83.5, 'end': 83.52, 'confidence': 0.981},
#       {'text': 'the', 'start': 83.52, 'end': 83.54, 'confidence': 0.973},
#       {'text': 'sound', 'start': 83.54, 'end': 83.56, 'confidence': 0.972},
#       {'text': 'of', 'start': 83.56, 'end': 83.58, 'confidence': 0.981},
#       {'text': 'the', 'start': 83.58, 'end': 83.6, 'confidence': 0.972},
#       {'text': 'sound', 'start': 83.6, 'end': 83.62, 'confidence': 0.971},
#       {'text': 'of', 'start': 83.62, 'end': 83.64, 'confidence': 0.981},
#       {'text': 'the', 'start': 83.64, 'end': 83.66, 'confidence': 0.972},
#       {'text': 'sound', 'start': 83.66, 'end': 83.68, 'confidence': 0.972},
#       {'text': 'of', 'start': 83.68, 'end': 83.7, 'confidence': 0.982},
#       {'text': 'the', 'start': 83.7, 'end': 83.72, 'confidence': 0.971},
#       {'text': 'sound', 'start': 83.72, 'end': 83.74, 'confidence': 0.972},
#       {'text': 'of', 'start': 83.74, 'end': 83.76, 'confidence': 0.982},
#       {'text': 'the', 'start': 83.76, 'end': 83.78, 'confidence': 0.973},
#       {'text': 'sound', 'start': 83.78, 'end': 83.8, 'confidence': 0.971},
#       {'text': 'of', 'start': 83.8, 'end': 83.82, 'confidence': 0.983},
#       {'text': 'the', 'start': 83.82, 'end': 87.12, 'confidence': 0.972},
#       {'text': 'sound', 'start': 87.12, 'end': 87.24, 'confidence': 0.969},
#       {'text': 'of', 'start': 87.24, 'end': 87.26, 'confidence': 0.981},
#       {'text': 'the', 'start': 87.26, 'end': 87.28, 'confidence': 0.975},
#       {'text': 'sound', 'start': 87.28, 'end': 87.3, 'confidence': 0.97},
#       {'text': 'of', 'start': 87.3, 'end': 87.32, 'confidence': 0.981},
#       {'text': 'the', 'start': 87.32, 'end': 87.34, 'confidence': 0.972},
#       {'text': 'sound', 'start': 87.34, 'end': 87.36, 'confidence': 0.97},
#       {'text': 'of', 'start': 87.36, 'end': 87.82, 'confidence': 0.982},
#       {'text': 'the', 'start': 87.82, 'end': 87.84, 'confidence': 0.972},
#       {'text': 'sound', 'start': 87.84, 'end': 87.86, 'confidence': 0.97},
#       {'text': 'of', 'start': 87.86, 'end': 87.88, 'confidence': 0.981},
#       {'text': 'the', 'start': 87.88, 'end': 87.9, 'confidence': 0.972},
#       {'text': 'sound', 'start': 87.9, 'end': 87.92, 'confidence': 0.971},
#       {'text': 'of', 'start': 87.92, 'end': 87.94, 'confidence': 0.982},
#       {'text': 'the', 'start': 87.94, 'end': 87.96, 'confidence': 0.97},
#       {'text': 'sound', 'start': 87.96, 'end': 88.02, 'confidence': 0.97},
#       {'text': 'of', 'start': 88.02, 'end': 89.54, 'confidence': 0.982},
#       {'text': 'the', 'start': 89.54, 'end': 89.6, 'confidence': 0.969},
#       {'text': 'sound', 'start': 89.6, 'end': 89.98, 'confidence': 0.97},
#       {'text': 'of', 'start': 89.98, 'end': 90.12, 'confidence': 0.982},
#       {'text': 'the', 'start': 90.12, 'end': 90.26, 'confidence': 0.968},
#       {'text': 'sound', 'start': 90.26, 'end': 90.28, 'confidence': 0.97},
#       {'text': 'of', 'start': 90.28, 'end': 94.3, 'confidence': 0.982},
#       {'text': 'the', 'start': 94.3, 'end': 94.62, 'confidence': 0.967},
#       {'text': 'sound', 'start': 94.62, 'end': 94.98, 'confidence': 0.969}]},
#     {'id': 2,
#      'start': 95.0,
#      'end': 124.98,
#      'text': ' the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound',
#      'no_speech_prob': 0.4887368977069855,
#      'confidence': 0.972,
#      'words': [{'text': 'the',
#        'start': 95.0,
#        'end': 96.42,
#        'confidence': 0.324},
#       {'text': 'sound', 'start': 96.42, 'end': 96.82, 'confidence': 0.984},
#       {'text': 'of', 'start': 96.82, 'end': 96.84, 'confidence': 0.97},
#       {'text': 'the', 'start': 96.84, 'end': 96.86, 'confidence': 0.951},
#       {'text': 'sound', 'start': 96.86, 'end': 96.96, 'confidence': 0.956},
#       {'text': 'of', 'start': 96.96, 'end': 97.46, 'confidence': 0.965},
#       {'text': 'the', 'start': 97.46, 'end': 97.48, 'confidence': 0.971},
#       {'text': 'sound', 'start': 97.48, 'end': 98.16, 'confidence': 0.956},
#       {'text': 'of', 'start': 98.16, 'end': 98.18, 'confidence': 0.971},
#       {'text': 'the', 'start': 98.18, 'end': 99.62, 'confidence': 0.976},
#       {'text': 'sound', 'start': 99.62, 'end': 99.8, 'confidence': 0.958},
#       {'text': 'of', 'start': 99.8, 'end': 99.82, 'confidence': 0.976},
#       {'text': 'the', 'start': 99.82, 'end': 101.64, 'confidence': 0.976},
#       {'text': 'sound', 'start': 101.64, 'end': 101.66, 'confidence': 0.957},
#       {'text': 'of', 'start': 101.66, 'end': 102.24, 'confidence': 0.979},
#       {'text': 'the', 'start': 102.24, 'end': 102.38, 'confidence': 0.977},
#       {'text': 'sound', 'start': 102.38, 'end': 102.4, 'confidence': 0.956},
#       {'text': 'of', 'start': 102.4, 'end': 102.52, 'confidence': 0.981},
#       {'text': 'the', 'start': 102.52, 'end': 103.6, 'confidence': 0.976},
#       {'text': 'sound', 'start': 103.6, 'end': 103.62, 'confidence': 0.957},
#       {'text': 'of', 'start': 103.62, 'end': 104.26, 'confidence': 0.982},
#       {'text': 'the', 'start': 104.26, 'end': 105.44, 'confidence': 0.975},
#       {'text': 'sound', 'start': 105.44, 'end': 105.46, 'confidence': 0.956},
#       {'text': 'of', 'start': 105.46, 'end': 105.48, 'confidence': 0.982},
#       {'text': 'the', 'start': 105.48, 'end': 105.5, 'confidence': 0.976},
#       {'text': 'sound', 'start': 105.5, 'end': 105.68, 'confidence': 0.958},
#       {'text': 'of', 'start': 105.68, 'end': 105.76, 'confidence': 0.983},
#       {'text': 'the', 'start': 105.76, 'end': 105.88, 'confidence': 0.976},
#       {'text': 'sound', 'start': 105.88, 'end': 106.0, 'confidence': 0.96},
#       {'text': 'of', 'start': 106.0, 'end': 106.12, 'confidence': 0.984},
#       {'text': 'the', 'start': 106.12, 'end': 106.26, 'confidence': 0.975},
#       {'text': 'sound', 'start': 106.26, 'end': 106.28, 'confidence': 0.961},
#       {'text': 'of', 'start': 106.28, 'end': 106.3, 'confidence': 0.984},
#       {'text': 'the', 'start': 106.3, 'end': 106.32, 'confidence': 0.978},
#       {'text': 'sound', 'start': 106.32, 'end': 106.34, 'confidence': 0.964},
#       {'text': 'of', 'start': 106.34, 'end': 106.36, 'confidence': 0.985},
#       {'text': 'the', 'start': 106.36, 'end': 106.84, 'confidence': 0.977},
#       {'text': 'sound', 'start': 106.84, 'end': 107.34, 'confidence': 0.964},
#       {'text': 'of', 'start': 107.34, 'end': 107.36, 'confidence': 0.985},
#       {'text': 'the', 'start': 107.36, 'end': 107.4, 'confidence': 0.977},
#       {'text': 'sound', 'start': 107.4, 'end': 107.42, 'confidence': 0.965},
#       {'text': 'of', 'start': 107.42, 'end': 107.44, 'confidence': 0.985},
#       {'text': 'the', 'start': 107.44, 'end': 108.26, 'confidence': 0.978},
#       {'text': 'sound', 'start': 108.26, 'end': 109.14, 'confidence': 0.966},
#       {'text': 'of', 'start': 109.14, 'end': 109.16, 'confidence': 0.986},
#       {'text': 'the', 'start': 109.16, 'end': 109.18, 'confidence': 0.977},
#       {'text': 'sound', 'start': 109.18, 'end': 109.2, 'confidence': 0.967},
#       {'text': 'of', 'start': 109.2, 'end': 109.42, 'confidence': 0.986},
#       {'text': 'the', 'start': 109.42, 'end': 109.44, 'confidence': 0.978},
#       {'text': 'sound', 'start': 109.44, 'end': 109.46, 'confidence': 0.968},
#       {'text': 'of', 'start': 109.46, 'end': 109.48, 'confidence': 0.987},
#       {'text': 'the', 'start': 109.48, 'end': 109.5, 'confidence': 0.977},
#       {'text': 'sound', 'start': 109.5, 'end': 111.26, 'confidence': 0.969},
#       {'text': 'of', 'start': 111.26, 'end': 111.34, 'confidence': 0.987},
#       {'text': 'the', 'start': 111.34, 'end': 111.36, 'confidence': 0.977},
#       {'text': 'sound', 'start': 111.36, 'end': 111.38, 'confidence': 0.969},
#       {'text': 'of', 'start': 111.38, 'end': 111.4, 'confidence': 0.988},
#       {'text': 'the', 'start': 111.4, 'end': 111.42, 'confidence': 0.976},
#       {'text': 'sound', 'start': 111.42, 'end': 111.44, 'confidence': 0.969},
#       {'text': 'of', 'start': 111.44, 'end': 111.46, 'confidence': 0.988},
#       {'text': 'the', 'start': 111.46, 'end': 111.64, 'confidence': 0.976},
#       {'text': 'sound', 'start': 111.64, 'end': 112.14, 'confidence': 0.969},
#       {'text': 'of', 'start': 112.14, 'end': 112.3, 'confidence': 0.988},
#       {'text': 'the', 'start': 112.3, 'end': 112.32, 'confidence': 0.976},
#       {'text': 'sound', 'start': 112.32, 'end': 112.34, 'confidence': 0.97},
#       {'text': 'of', 'start': 112.34, 'end': 112.36, 'confidence': 0.989},
#       {'text': 'the', 'start': 112.36, 'end': 112.38, 'confidence': 0.975},
#       {'text': 'sound', 'start': 112.38, 'end': 112.68, 'confidence': 0.97},
#       {'text': 'of', 'start': 112.68, 'end': 112.76, 'confidence': 0.988},
#       {'text': 'the', 'start': 112.76, 'end': 112.88, 'confidence': 0.976},
#       {'text': 'sound', 'start': 112.88, 'end': 112.9, 'confidence': 0.97},
#       {'text': 'of', 'start': 112.9, 'end': 112.92, 'confidence': 0.989},
#       {'text': 'the', 'start': 112.92, 'end': 112.94, 'confidence': 0.977},
#       {'text': 'sound', 'start': 112.94, 'end': 112.96, 'confidence': 0.972},
#       {'text': 'of', 'start': 112.96, 'end': 112.98, 'confidence': 0.989},
#       {'text': 'the', 'start': 112.98, 'end': 113.0, 'confidence': 0.975},
#       {'text': 'sound', 'start': 113.0, 'end': 113.02, 'confidence': 0.971},
#       {'text': 'of', 'start': 113.02, 'end': 114.8, 'confidence': 0.989},
#       {'text': 'the', 'start': 114.8, 'end': 114.82, 'confidence': 0.977},
#       {'text': 'sound', 'start': 114.82, 'end': 114.84, 'confidence': 0.973},
#       {'text': 'of', 'start': 114.84, 'end': 114.86, 'confidence': 0.99},
#       {'text': 'the', 'start': 114.86, 'end': 114.88, 'confidence': 0.977},
#       {'text': 'sound', 'start': 114.88, 'end': 114.9, 'confidence': 0.973},
#       {'text': 'of', 'start': 114.9, 'end': 114.92, 'confidence': 0.99},
#       {'text': 'the', 'start': 114.92, 'end': 114.94, 'confidence': 0.977},
#       {'text': 'sound', 'start': 114.94, 'end': 114.96, 'confidence': 0.973},
#       {'text': 'of', 'start': 114.96, 'end': 114.98, 'confidence': 0.99},
#       {'text': 'the', 'start': 114.98, 'end': 115.0, 'confidence': 0.977},
#       {'text': 'sound', 'start': 115.0, 'end': 115.02, 'confidence': 0.973},
#       {'text': 'of', 'start': 115.02, 'end': 115.04, 'confidence': 0.99},
#       {'text': 'the', 'start': 115.04, 'end': 115.06, 'confidence': 0.977},
#       {'text': 'sound', 'start': 115.06, 'end': 115.08, 'confidence': 0.973},
#       {'text': 'of', 'start': 115.08, 'end': 115.1, 'confidence': 0.989},
#       {'text': 'the', 'start': 115.1, 'end': 115.12, 'confidence': 0.977},
#       {'text': 'sound', 'start': 115.12, 'end': 115.14, 'confidence': 0.973},
#       {'text': 'of', 'start': 115.14, 'end': 115.16, 'confidence': 0.99},
#       {'text': 'the', 'start': 115.16, 'end': 115.18, 'confidence': 0.977},
#       {'text': 'sound', 'start': 115.18, 'end': 115.2, 'confidence': 0.974},
#       {'text': 'of', 'start': 115.2, 'end': 115.22, 'confidence': 0.99},
#       {'text': 'the', 'start': 115.22, 'end': 115.24, 'confidence': 0.975},
#       {'text': 'sound', 'start': 115.24, 'end': 115.26, 'confidence': 0.973},
#       {'text': 'of', 'start': 115.26, 'end': 115.28, 'confidence': 0.99},
#       {'text': 'the', 'start': 115.28, 'end': 115.3, 'confidence': 0.975},
#       {'text': 'sound', 'start': 115.3, 'end': 115.32, 'confidence': 0.973},
#       {'text': 'of', 'start': 115.32, 'end': 116.26, 'confidence': 0.989},
#       {'text': 'the', 'start': 116.26, 'end': 116.28, 'confidence': 0.975},
#       {'text': 'sound', 'start': 116.28, 'end': 116.3, 'confidence': 0.973},
#       {'text': 'of', 'start': 116.3, 'end': 116.32, 'confidence': 0.99},
#       {'text': 'the', 'start': 116.32, 'end': 116.34, 'confidence': 0.974},
#       {'text': 'sound', 'start': 116.34, 'end': 116.36, 'confidence': 0.973},
#       {'text': 'of', 'start': 116.36, 'end': 116.38, 'confidence': 0.99},
#       {'text': 'the', 'start': 116.38, 'end': 116.4, 'confidence': 0.976},
#       {'text': 'sound', 'start': 116.4, 'end': 116.42, 'confidence': 0.974},
#       {'text': 'of', 'start': 116.42, 'end': 116.44, 'confidence': 0.99},
#       {'text': 'the', 'start': 116.44, 'end': 116.46, 'confidence': 0.975},
#       {'text': 'sound', 'start': 116.46, 'end': 116.48, 'confidence': 0.973},
#       {'text': 'of', 'start': 116.48, 'end': 116.5, 'confidence': 0.99},
#       {'text': 'the', 'start': 116.5, 'end': 116.52, 'confidence': 0.975},
#       {'text': 'sound', 'start': 116.52, 'end': 116.54, 'confidence': 0.973},
#       {'text': 'of', 'start': 116.54, 'end': 116.56, 'confidence': 0.99},
#       {'text': 'the', 'start': 116.56, 'end': 116.58, 'confidence': 0.974},
#       {'text': 'sound', 'start': 116.58, 'end': 116.6, 'confidence': 0.973},
#       {'text': 'of', 'start': 116.6, 'end': 116.62, 'confidence': 0.99},
#       {'text': 'the', 'start': 116.62, 'end': 116.64, 'confidence': 0.975},
#       {'text': 'sound', 'start': 116.64, 'end': 116.66, 'confidence': 0.973},
#       {'text': 'of', 'start': 116.66, 'end': 116.68, 'confidence': 0.99},
#       {'text': 'the', 'start': 116.68, 'end': 116.7, 'confidence': 0.975},
#       {'text': 'sound', 'start': 116.7, 'end': 116.72, 'confidence': 0.974},
#       {'text': 'of', 'start': 116.72, 'end': 116.96, 'confidence': 0.99},
#       {'text': 'the', 'start': 116.96, 'end': 116.98, 'confidence': 0.976},
#       {'text': 'sound', 'start': 116.98, 'end': 117.0, 'confidence': 0.973},
#       {'text': 'of', 'start': 117.0, 'end': 117.02, 'confidence': 0.989},
#       {'text': 'the', 'start': 117.02, 'end': 117.04, 'confidence': 0.975},
#       {'text': 'sound', 'start': 117.04, 'end': 117.06, 'confidence': 0.973},
#       {'text': 'of', 'start': 117.06, 'end': 117.08, 'confidence': 0.989},
#       {'text': 'the', 'start': 117.08, 'end': 117.1, 'confidence': 0.974},
#       {'text': 'sound', 'start': 117.1, 'end': 117.12, 'confidence': 0.974},
#       {'text': 'of', 'start': 117.12, 'end': 117.14, 'confidence': 0.989},
#       {'text': 'the', 'start': 117.14, 'end': 117.16, 'confidence': 0.974},
#       {'text': 'sound', 'start': 117.16, 'end': 117.18, 'confidence': 0.974},
#       {'text': 'of', 'start': 117.18, 'end': 117.2, 'confidence': 0.987},
#       {'text': 'the', 'start': 117.2, 'end': 117.22, 'confidence': 0.975},
#       {'text': 'sound', 'start': 117.22, 'end': 117.24, 'confidence': 0.973},
#       {'text': 'of', 'start': 117.24, 'end': 117.26, 'confidence': 0.989},
#       {'text': 'the', 'start': 117.26, 'end': 117.28, 'confidence': 0.973},
#       {'text': 'sound', 'start': 117.28, 'end': 117.3, 'confidence': 0.974},
#       {'text': 'of', 'start': 117.3, 'end': 117.32, 'confidence': 0.987},
#       {'text': 'the', 'start': 117.32, 'end': 117.34, 'confidence': 0.973},
#       {'text': 'sound', 'start': 117.34, 'end': 117.36, 'confidence': 0.972},
#       {'text': 'of', 'start': 117.36, 'end': 117.38, 'confidence': 0.986},
#       {'text': 'the', 'start': 117.38, 'end': 117.4, 'confidence': 0.974},
#       {'text': 'sound', 'start': 117.4, 'end': 117.42, 'confidence': 0.974},
#       {'text': 'of', 'start': 117.42, 'end': 117.44, 'confidence': 0.986},
#       {'text': 'the', 'start': 117.44, 'end': 117.46, 'confidence': 0.973},
#       {'text': 'sound', 'start': 117.46, 'end': 117.48, 'confidence': 0.973},
#       {'text': 'of', 'start': 117.48, 'end': 117.5, 'confidence': 0.986},
#       {'text': 'the', 'start': 117.5, 'end': 117.52, 'confidence': 0.971},
#       {'text': 'sound', 'start': 117.52, 'end': 117.54, 'confidence': 0.973},
#       {'text': 'of', 'start': 117.54, 'end': 117.56, 'confidence': 0.985},
#       {'text': 'the', 'start': 117.56, 'end': 117.58, 'confidence': 0.97},
#       {'text': 'sound', 'start': 117.58, 'end': 117.6, 'confidence': 0.974},
#       {'text': 'of', 'start': 117.6, 'end': 117.62, 'confidence': 0.985},
#       {'text': 'the', 'start': 117.62, 'end': 117.64, 'confidence': 0.972},
#       {'text': 'sound', 'start': 117.64, 'end': 117.66, 'confidence': 0.974},
#       {'text': 'of', 'start': 117.66, 'end': 117.68, 'confidence': 0.985},
#       {'text': 'the', 'start': 117.68, 'end': 117.7, 'confidence': 0.97},
#       {'text': 'sound', 'start': 117.7, 'end': 117.72, 'confidence': 0.975},
#       {'text': 'of', 'start': 117.72, 'end': 117.74, 'confidence': 0.984},
#       {'text': 'the', 'start': 117.74, 'end': 117.76, 'confidence': 0.97},
#       {'text': 'sound', 'start': 117.76, 'end': 117.78, 'confidence': 0.974},
#       {'text': 'of', 'start': 117.78, 'end': 117.8, 'confidence': 0.985},
#       {'text': 'the', 'start': 117.8, 'end': 117.82, 'confidence': 0.97},
#       {'text': 'sound', 'start': 117.82, 'end': 117.84, 'confidence': 0.975},
#       {'text': 'of', 'start': 117.84, 'end': 117.86, 'confidence': 0.985},
#       {'text': 'the', 'start': 117.86, 'end': 117.88, 'confidence': 0.97},
#       {'text': 'sound', 'start': 117.88, 'end': 117.9, 'confidence': 0.974},
#       {'text': 'of', 'start': 117.9, 'end': 117.92, 'confidence': 0.983},
#       {'text': 'the', 'start': 117.92, 'end': 117.94, 'confidence': 0.97},
#       {'text': 'sound', 'start': 117.94, 'end': 117.96, 'confidence': 0.974},
#       {'text': 'of', 'start': 117.96, 'end': 117.98, 'confidence': 0.984},
#       {'text': 'the', 'start': 117.98, 'end': 118.0, 'confidence': 0.97},
#       {'text': 'sound', 'start': 118.0, 'end': 118.02, 'confidence': 0.975},
#       {'text': 'of', 'start': 118.02, 'end': 118.04, 'confidence': 0.982},
#       {'text': 'the', 'start': 118.04, 'end': 118.06, 'confidence': 0.97},
#       {'text': 'sound', 'start': 118.06, 'end': 118.08, 'confidence': 0.975},
#       {'text': 'of', 'start': 118.08, 'end': 118.1, 'confidence': 0.982},
#       {'text': 'the', 'start': 118.1, 'end': 118.12, 'confidence': 0.971},
#       {'text': 'sound', 'start': 118.12, 'end': 118.14, 'confidence': 0.975},
#       {'text': 'of', 'start': 118.14, 'end': 118.16, 'confidence': 0.983},
#       {'text': 'the', 'start': 118.16, 'end': 118.18, 'confidence': 0.972},
#       {'text': 'sound', 'start': 118.18, 'end': 118.2, 'confidence': 0.974},
#       {'text': 'of', 'start': 118.2, 'end': 118.22, 'confidence': 0.984},
#       {'text': 'the', 'start': 118.22, 'end': 118.24, 'confidence': 0.967},
#       {'text': 'sound', 'start': 118.24, 'end': 118.26, 'confidence': 0.975},
#       {'text': 'of', 'start': 118.26, 'end': 118.28, 'confidence': 0.985},
#       {'text': 'the', 'start': 118.28, 'end': 118.3, 'confidence': 0.969},
#       {'text': 'sound', 'start': 118.3, 'end': 118.32, 'confidence': 0.975},
#       {'text': 'of', 'start': 118.32, 'end': 118.34, 'confidence': 0.985},
#       {'text': 'the', 'start': 118.34, 'end': 118.36, 'confidence': 0.969},
#       {'text': 'sound', 'start': 118.36, 'end': 118.38, 'confidence': 0.975},
#       {'text': 'of', 'start': 118.38, 'end': 118.4, 'confidence': 0.984},
#       {'text': 'the', 'start': 118.4, 'end': 118.42, 'confidence': 0.965},
#       {'text': 'sound', 'start': 118.42, 'end': 118.44, 'confidence': 0.977},
#       {'text': 'of', 'start': 118.44, 'end': 118.46, 'confidence': 0.984},
#       {'text': 'the', 'start': 118.46, 'end': 118.48, 'confidence': 0.972},
#       {'text': 'sound', 'start': 118.48, 'end': 118.5, 'confidence': 0.975},
#       {'text': 'of', 'start': 118.5, 'end': 118.52, 'confidence': 0.986},
#       {'text': 'the', 'start': 118.52, 'end': 118.54, 'confidence': 0.97},
#       {'text': 'sound', 'start': 118.54, 'end': 118.56, 'confidence': 0.975},
#       {'text': 'of', 'start': 118.56, 'end': 118.58, 'confidence': 0.986},
#       {'text': 'the', 'start': 118.58, 'end': 118.6, 'confidence': 0.968},
#       {'text': 'sound', 'start': 118.6, 'end': 118.62, 'confidence': 0.976},
#       {'text': 'of', 'start': 118.62, 'end': 118.64, 'confidence': 0.986},
#       {'text': 'the', 'start': 118.64, 'end': 118.66, 'confidence': 0.966},
#       {'text': 'sound', 'start': 118.66, 'end': 118.68, 'confidence': 0.977},
#       {'text': 'of', 'start': 118.68, 'end': 118.7, 'confidence': 0.989},
#       {'text': 'the', 'start': 118.7, 'end': 118.72, 'confidence': 0.969},
#       {'text': 'sound', 'start': 118.72, 'end': 118.74, 'confidence': 0.978},
#       {'text': 'of', 'start': 118.74, 'end': 124.88, 'confidence': 0.988},
#       {'text': 'the', 'start': 124.88, 'end': 124.9, 'confidence': 0.97},
#       {'text': 'sound', 'start': 124.9, 'end': 124.98, 'confidence': 0.978}]},
#     {'id': 3,
#      'start': 125.0,
#      'end': 154.98,
#      'text': ' sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of the sound of',
#      'no_speech_prob': 0.890712559223175,
#      'confidence': 0.975,
#      'words': [{'text': 'sound',
#        'start': 125.0,
#        'end': 129.52,
#        'confidence': 0.219},
#       {'text': 'of', 'start': 129.52, 'end': 129.54, 'confidence': 0.941},
#       {'text': 'the', 'start': 129.54, 'end': 129.56, 'confidence': 0.957},
#       {'text': 'sound', 'start': 129.56, 'end': 129.58, 'confidence': 0.965},
#       {'text': 'of', 'start': 129.58, 'end': 129.6, 'confidence': 0.982},
#       {'text': 'the', 'start': 129.6, 'end': 129.62, 'confidence': 0.978},
#       {'text': 'sound', 'start': 129.62, 'end': 129.64, 'confidence': 0.965},
#       {'text': 'of', 'start': 129.64, 'end': 129.66, 'confidence': 0.983},
#       {'text': 'the', 'start': 129.66, 'end': 129.68, 'confidence': 0.982},
#       {'text': 'sound', 'start': 129.68, 'end': 129.7, 'confidence': 0.965},
#       {'text': 'of', 'start': 129.7, 'end': 129.72, 'confidence': 0.984},
#       {'text': 'the', 'start': 129.72, 'end': 129.74, 'confidence': 0.982},
#       {'text': 'sound', 'start': 129.74, 'end': 129.76, 'confidence': 0.962},
#       {'text': 'of', 'start': 129.76, 'end': 129.78, 'confidence': 0.985},
#       {'text': 'the', 'start': 129.78, 'end': 129.8, 'confidence': 0.983},
#       {'text': 'sound', 'start': 129.8, 'end': 129.82, 'confidence': 0.962},
#       {'text': 'of', 'start': 129.82, 'end': 131.66, 'confidence': 0.984},
#       {'text': 'the', 'start': 131.66, 'end': 131.68, 'confidence': 0.982},
#       {'text': 'sound', 'start': 131.68, 'end': 131.7, 'confidence': 0.96},
#       {'text': 'of', 'start': 131.7, 'end': 131.72, 'confidence': 0.984},
#       {'text': 'the', 'start': 131.72, 'end': 131.76, 'confidence': 0.982},
#       {'text': 'sound', 'start': 131.76, 'end': 131.78, 'confidence': 0.96},
#       {'text': 'of', 'start': 131.78, 'end': 131.86, 'confidence': 0.985},
#       {'text': 'the', 'start': 131.86, 'end': 131.94, 'confidence': 0.983},
#       {'text': 'sound', 'start': 131.94, 'end': 131.96, 'confidence': 0.962},
#       {'text': 'of', 'start': 131.96, 'end': 132.24, 'confidence': 0.985},
#       {'text': 'the', 'start': 132.24, 'end': 132.26, 'confidence': 0.983},
#       {'text': 'sound', 'start': 132.26, 'end': 132.28, 'confidence': 0.964},
#       {'text': 'of', 'start': 132.28, 'end': 132.3, 'confidence': 0.985},
#       {'text': 'the', 'start': 132.3, 'end': 132.4, 'confidence': 0.983},
#       {'text': 'sound', 'start': 132.4, 'end': 132.42, 'confidence': 0.965},
#       {'text': 'of', 'start': 132.42, 'end': 132.48, 'confidence': 0.986},
#       {'text': 'the', 'start': 132.48, 'end': 135.02, 'confidence': 0.983},
#       {'text': 'sound', 'start': 135.02, 'end': 135.04, 'confidence': 0.967},
#       {'text': 'of', 'start': 135.04, 'end': 135.06, 'confidence': 0.987},
#       {'text': 'the', 'start': 135.06, 'end': 135.08, 'confidence': 0.984},
#       {'text': 'sound', 'start': 135.08, 'end': 135.1, 'confidence': 0.968},
#       {'text': 'of', 'start': 135.1, 'end': 135.12, 'confidence': 0.987},
#       {'text': 'the', 'start': 135.12, 'end': 135.14, 'confidence': 0.984},
#       {'text': 'sound', 'start': 135.14, 'end': 135.16, 'confidence': 0.969},
#       {'text': 'of', 'start': 135.16, 'end': 135.18, 'confidence': 0.987},
#       {'text': 'the', 'start': 135.18, 'end': 135.8, 'confidence': 0.985},
#       {'text': 'sound', 'start': 135.8, 'end': 135.82, 'confidence': 0.97},
#       {'text': 'of', 'start': 135.82, 'end': 135.86, 'confidence': 0.988},
#       {'text': 'the', 'start': 135.86, 'end': 135.9, 'confidence': 0.985},
#       {'text': 'sound', 'start': 135.9, 'end': 135.92, 'confidence': 0.971},
#       {'text': 'of', 'start': 135.92, 'end': 135.98, 'confidence': 0.988},
#       {'text': 'the', 'start': 135.98, 'end': 136.16, 'confidence': 0.984},
#       {'text': 'sound', 'start': 136.16, 'end': 136.18, 'confidence': 0.972},
#       {'text': 'of', 'start': 136.18, 'end': 136.2, 'confidence': 0.988},
#       {'text': 'the', 'start': 136.2, 'end': 137.36, 'confidence': 0.984},
#       {'text': 'sound', 'start': 137.36, 'end': 137.38, 'confidence': 0.972},
#       {'text': 'of', 'start': 137.38, 'end': 140.66, 'confidence': 0.989},
#       {'text': 'the', 'start': 140.66, 'end': 140.68, 'confidence': 0.984},
#       {'text': 'sound', 'start': 140.68, 'end': 140.7, 'confidence': 0.973},
#       {'text': 'of', 'start': 140.7, 'end': 140.72, 'confidence': 0.99},
#       {'text': 'the', 'start': 140.72, 'end': 140.74, 'confidence': 0.984},
#       {'text': 'sound', 'start': 140.74, 'end': 140.76, 'confidence': 0.973},
#       {'text': 'of', 'start': 140.76, 'end': 140.78, 'confidence': 0.99},
#       {'text': 'the', 'start': 140.78, 'end': 140.8, 'confidence': 0.984},
#       {'text': 'sound', 'start': 140.8, 'end': 140.82, 'confidence': 0.973},
#       {'text': 'of', 'start': 140.82, 'end': 140.84, 'confidence': 0.991},
#       {'text': 'the', 'start': 140.84, 'end': 140.86, 'confidence': 0.983},
#       {'text': 'sound', 'start': 140.86, 'end': 140.88, 'confidence': 0.974},
#       {'text': 'of', 'start': 140.88, 'end': 140.9, 'confidence': 0.991},
#       {'text': 'the', 'start': 140.9, 'end': 140.92, 'confidence': 0.982},
#       {'text': 'sound', 'start': 140.92, 'end': 140.94, 'confidence': 0.973},
#       {'text': 'of', 'start': 140.94, 'end': 140.96, 'confidence': 0.991},
#       {'text': 'the', 'start': 140.96, 'end': 140.98, 'confidence': 0.983},
#       {'text': 'sound', 'start': 140.98, 'end': 141.0, 'confidence': 0.974},
#       {'text': 'of', 'start': 141.0, 'end': 141.02, 'confidence': 0.991},
#       {'text': 'the', 'start': 141.02, 'end': 141.04, 'confidence': 0.983},
#       {'text': 'sound', 'start': 141.04, 'end': 141.06, 'confidence': 0.975},
#       {'text': 'of', 'start': 141.06, 'end': 141.08, 'confidence': 0.991},
#       {'text': 'the', 'start': 141.08, 'end': 141.1, 'confidence': 0.982},
#       {'text': 'sound', 'start': 141.1, 'end': 141.12, 'confidence': 0.975},
#       {'text': 'of', 'start': 141.12, 'end': 141.14, 'confidence': 0.991},
#       {'text': 'the', 'start': 141.14, 'end': 141.16, 'confidence': 0.983},
#       {'text': 'sound', 'start': 141.16, 'end': 141.18, 'confidence': 0.976},
#       {'text': 'of', 'start': 141.18, 'end': 141.2, 'confidence': 0.992},
#       {'text': 'the', 'start': 141.2, 'end': 141.22, 'confidence': 0.983},
#       {'text': 'sound', 'start': 141.22, 'end': 141.24, 'confidence': 0.977},
#       {'text': 'of', 'start': 141.24, 'end': 141.26, 'confidence': 0.992},
#       {'text': 'the', 'start': 141.26, 'end': 141.28, 'confidence': 0.983},
#       {'text': 'sound', 'start': 141.28, 'end': 141.3, 'confidence': 0.977},
#       {'text': 'of', 'start': 141.3, 'end': 141.32, 'confidence': 0.992},
#       {'text': 'the', 'start': 141.32, 'end': 141.34, 'confidence': 0.983},
#       {'text': 'sound', 'start': 141.34, 'end': 141.36, 'confidence': 0.977},
#       {'text': 'of', 'start': 141.36, 'end': 141.38, 'confidence': 0.992},
#       {'text': 'the', 'start': 141.38, 'end': 141.4, 'confidence': 0.983},
#       {'text': 'sound', 'start': 141.4, 'end': 141.42, 'confidence': 0.976},
#       {'text': 'of', 'start': 141.42, 'end': 141.44, 'confidence': 0.992},
#       {'text': 'the', 'start': 141.44, 'end': 141.46, 'confidence': 0.983},
#       {'text': 'sound', 'start': 141.46, 'end': 141.48, 'confidence': 0.977},
#       {'text': 'of', 'start': 141.48, 'end': 141.5, 'confidence': 0.992},
#       {'text': 'the', 'start': 141.5, 'end': 141.52, 'confidence': 0.983},
#       {'text': 'sound', 'start': 141.52, 'end': 141.54, 'confidence': 0.977},
#       {'text': 'of', 'start': 141.54, 'end': 141.96, 'confidence': 0.992},
#       {'text': 'the', 'start': 141.96, 'end': 141.98, 'confidence': 0.982},
#       {'text': 'sound', 'start': 141.98, 'end': 142.0, 'confidence': 0.977},
#       {'text': 'of', 'start': 142.0, 'end': 142.02, 'confidence': 0.992},
#       {'text': 'the', 'start': 142.02, 'end': 142.04, 'confidence': 0.981},
#       {'text': 'sound', 'start': 142.04, 'end': 142.06, 'confidence': 0.977},
#       {'text': 'of', 'start': 142.06, 'end': 142.08, 'confidence': 0.992},
#       {'text': 'the', 'start': 142.08, 'end': 142.1, 'confidence': 0.981},
#       {'text': 'sound', 'start': 142.1, 'end': 142.12, 'confidence': 0.977},
#       {'text': 'of', 'start': 142.12, 'end': 142.14, 'confidence': 0.992},
#       {'text': 'the', 'start': 142.14, 'end': 142.22, 'confidence': 0.982},
#       {'text': 'sound', 'start': 142.22, 'end': 142.24, 'confidence': 0.977},
#       {'text': 'of', 'start': 142.24, 'end': 142.26, 'confidence': 0.993},
#       {'text': 'the', 'start': 142.26, 'end': 142.28, 'confidence': 0.981},
#       {'text': 'sound', 'start': 142.28, 'end': 142.3, 'confidence': 0.977},
#       {'text': 'of', 'start': 142.3, 'end': 142.32, 'confidence': 0.993},
#       {'text': 'the', 'start': 142.32, 'end': 142.34, 'confidence': 0.981},
#       {'text': 'sound', 'start': 142.34, 'end': 142.36, 'confidence': 0.977},
#       {'text': 'of', 'start': 142.36, 'end': 142.38, 'confidence': 0.993},
#       {'text': 'the', 'start': 142.38, 'end': 142.4, 'confidence': 0.981},
#       {'text': 'sound', 'start': 142.4, 'end': 142.42, 'confidence': 0.978},
#       {'text': 'of', 'start': 142.42, 'end': 142.44, 'confidence': 0.993},
#       {'text': 'the', 'start': 142.44, 'end': 142.46, 'confidence': 0.981},
#       {'text': 'sound', 'start': 142.46, 'end': 142.48, 'confidence': 0.977},
#       {'text': 'of', 'start': 142.48, 'end': 142.5, 'confidence': 0.993},
#       {'text': 'the', 'start': 142.5, 'end': 142.52, 'confidence': 0.982},
#       {'text': 'sound', 'start': 142.52, 'end': 142.54, 'confidence': 0.978},
#       {'text': 'of', 'start': 142.54, 'end': 142.56, 'confidence': 0.993},
#       {'text': 'the', 'start': 142.56, 'end': 142.58, 'confidence': 0.982},
#       {'text': 'sound', 'start': 142.58, 'end': 142.6, 'confidence': 0.979},
#       {'text': 'of', 'start': 142.6, 'end': 142.62, 'confidence': 0.992},
#       {'text': 'the', 'start': 142.62, 'end': 142.64, 'confidence': 0.981},
#       {'text': 'sound', 'start': 142.64, 'end': 142.66, 'confidence': 0.978},
#       {'text': 'of', 'start': 142.66, 'end': 142.68, 'confidence': 0.992},
#       {'text': 'the', 'start': 142.68, 'end': 142.7, 'confidence': 0.982},
#       {'text': 'sound', 'start': 142.7, 'end': 142.72, 'confidence': 0.978},
#       {'text': 'of', 'start': 142.72, 'end': 142.74, 'confidence': 0.993},
#       {'text': 'the', 'start': 142.74, 'end': 142.76, 'confidence': 0.981},
#       {'text': 'sound', 'start': 142.76, 'end': 142.78, 'confidence': 0.978},
#       {'text': 'of', 'start': 142.78, 'end': 142.8, 'confidence': 0.993},
#       {'text': 'the', 'start': 142.8, 'end': 142.82, 'confidence': 0.981},
#       {'text': 'sound', 'start': 142.82, 'end': 142.84, 'confidence': 0.977},
#       {'text': 'of', 'start': 142.84, 'end': 142.86, 'confidence': 0.993},
#       {'text': 'the', 'start': 142.86, 'end': 142.88, 'confidence': 0.981},
#       {'text': 'sound', 'start': 142.88, 'end': 142.9, 'confidence': 0.978},
#       {'text': 'of', 'start': 142.9, 'end': 142.92, 'confidence': 0.993},
#       {'text': 'the', 'start': 142.92, 'end': 142.94, 'confidence': 0.981},
#       {'text': 'sound', 'start': 142.94, 'end': 142.96, 'confidence': 0.977},
#       {'text': 'of', 'start': 142.96, 'end': 142.98, 'confidence': 0.994},
#       {'text': 'the', 'start': 142.98, 'end': 143.0, 'confidence': 0.981},
#       {'text': 'sound', 'start': 143.0, 'end': 143.02, 'confidence': 0.977},
#       {'text': 'of', 'start': 143.02, 'end': 143.04, 'confidence': 0.993},
#       {'text': 'the', 'start': 143.04, 'end': 143.06, 'confidence': 0.98},
#       {'text': 'sound', 'start': 143.06, 'end': 143.08, 'confidence': 0.978},
#       {'text': 'of', 'start': 143.08, 'end': 143.1, 'confidence': 0.994},
#       {'text': 'the', 'start': 143.1, 'end': 143.12, 'confidence': 0.981},
#       {'text': 'sound', 'start': 143.12, 'end': 143.14, 'confidence': 0.976},
#       {'text': 'of', 'start': 143.14, 'end': 143.16, 'confidence': 0.994},
#       {'text': 'the', 'start': 143.16, 'end': 143.18, 'confidence': 0.98},
#       {'text': 'sound', 'start': 143.18, 'end': 143.2, 'confidence': 0.977},
#       {'text': 'of', 'start': 143.2, 'end': 143.22, 'confidence': 0.994},
#       {'text': 'the', 'start': 143.22, 'end': 143.24, 'confidence': 0.98},
#       {'text': 'sound', 'start': 143.24, 'end': 143.26, 'confidence': 0.977},
#       {'text': 'of', 'start': 143.26, 'end': 143.28, 'confidence': 0.993},
#       {'text': 'the', 'start': 143.28, 'end': 143.3, 'confidence': 0.979},
#       {'text': 'sound', 'start': 143.3, 'end': 143.32, 'confidence': 0.977},
#       {'text': 'of', 'start': 143.32, 'end': 143.34, 'confidence': 0.994},
#       {'text': 'the', 'start': 143.34, 'end': 143.36, 'confidence': 0.979},
#       {'text': 'sound', 'start': 143.36, 'end': 143.38, 'confidence': 0.977},
#       {'text': 'of', 'start': 143.38, 'end': 143.4, 'confidence': 0.994},
#       {'text': 'the', 'start': 143.4, 'end': 143.42, 'confidence': 0.98},
#       {'text': 'sound', 'start': 143.42, 'end': 143.44, 'confidence': 0.978},
#       {'text': 'of', 'start': 143.44, 'end': 143.46, 'confidence': 0.993},
#       {'text': 'the', 'start': 143.46, 'end': 143.48, 'confidence': 0.98},
#       {'text': 'sound', 'start': 143.48, 'end': 143.5, 'confidence': 0.978},
#       {'text': 'of', 'start': 143.5, 'end': 143.52, 'confidence': 0.994},
#       {'text': 'the', 'start': 143.52, 'end': 143.54, 'confidence': 0.979},
#       {'text': 'sound', 'start': 143.54, 'end': 143.56, 'confidence': 0.977},
#       {'text': 'of', 'start': 143.56, 'end': 143.58, 'confidence': 0.994},
#       {'text': 'the', 'start': 143.58, 'end': 143.6, 'confidence': 0.979},
#       {'text': 'sound', 'start': 143.6, 'end': 143.62, 'confidence': 0.977},
#       {'text': 'of', 'start': 143.62, 'end': 143.64, 'confidence': 0.994},
#       {'text': 'the', 'start': 143.64, 'end': 143.66, 'confidence': 0.98},
#       {'text': 'sound', 'start': 143.66, 'end': 143.68, 'confidence': 0.977},
#       {'text': 'of', 'start': 143.68, 'end': 143.7, 'confidence': 0.994},
#       {'text': 'the', 'start': 143.7, 'end': 143.72, 'confidence': 0.979},
#       {'text': 'sound', 'start': 143.72, 'end': 143.74, 'confidence': 0.977},
#       {'text': 'of', 'start': 143.74, 'end': 143.76, 'confidence': 0.993},
#       {'text': 'the', 'start': 143.76, 'end': 143.78, 'confidence': 0.979},
#       {'text': 'sound', 'start': 143.78, 'end': 143.8, 'confidence': 0.977},
#       {'text': 'of', 'start': 143.8, 'end': 143.82, 'confidence': 0.994},
#       {'text': 'the', 'start': 143.82, 'end': 143.84, 'confidence': 0.978},
#       {'text': 'sound', 'start': 143.84, 'end': 143.86, 'confidence': 0.976},
#       {'text': 'of', 'start': 143.86, 'end': 143.88, 'confidence': 0.994},
#       {'text': 'the', 'start': 143.88, 'end': 143.9, 'confidence': 0.979},
#       {'text': 'sound', 'start': 143.9, 'end': 143.92, 'confidence': 0.976},
#       {'text': 'of', 'start': 143.92, 'end': 143.94, 'confidence': 0.993},
#       {'text': 'the', 'start': 143.94, 'end': 143.96, 'confidence': 0.975},
#       {'text': 'sound', 'start': 143.96, 'end': 143.98, 'confidence': 0.975},
#       {'text': 'of', 'start': 143.98, 'end': 144.0, 'confidence': 0.993},
#       {'text': 'the', 'start': 144.0, 'end': 144.02, 'confidence': 0.975},
#       {'text': 'sound', 'start': 144.02, 'end': 144.04, 'confidence': 0.975},
#       {'text': 'of', 'start': 144.04, 'end': 146.04, 'confidence': 0.993},
#       {'text': 'the', 'start': 146.04, 'end': 146.06, 'confidence': 0.975},
#       {'text': 'sound', 'start': 146.06, 'end': 146.08, 'confidence': 0.976},
#       {'text': 'of', 'start': 146.08, 'end': 146.1, 'confidence': 0.994},
#       {'text': 'the', 'start': 146.1, 'end': 146.12, 'confidence': 0.977},
#       {'text': 'sound', 'start': 146.12, 'end': 146.14, 'confidence': 0.975},
#       {'text': 'of', 'start': 146.14, 'end': 146.16, 'confidence': 0.992},
#       {'text': 'the', 'start': 146.16, 'end': 146.18, 'confidence': 0.976},
#       {'text': 'sound', 'start': 146.18, 'end': 146.2, 'confidence': 0.975},
#       {'text': 'of', 'start': 146.2, 'end': 147.36, 'confidence': 0.992},
#       {'text': 'the', 'start': 147.36, 'end': 147.38, 'confidence': 0.972},
#       {'text': 'sound', 'start': 147.38, 'end': 147.4, 'confidence': 0.975},
#       {'text': 'of', 'start': 147.4, 'end': 147.42, 'confidence': 0.992},
#       {'text': 'the', 'start': 147.42, 'end': 147.44, 'confidence': 0.975},
#       {'text': 'sound', 'start': 147.44, 'end': 147.46, 'confidence': 0.976},
#       {'text': 'of', 'start': 147.46, 'end': 147.48, 'confidence': 0.992},
#       {'text': 'the', 'start': 147.48, 'end': 147.5, 'confidence': 0.974},
#       {'text': 'sound', 'start': 147.5, 'end': 147.52, 'confidence': 0.975},
#       {'text': 'of', 'start': 147.52, 'end': 149.22, 'confidence': 0.992},
#       {'text': 'the', 'start': 149.22, 'end': 149.24, 'confidence': 0.973},
#       {'text': 'sound', 'start': 149.24, 'end': 149.26, 'confidence': 0.977},
#       {'text': 'of', 'start': 149.26, 'end': 154.98, 'confidence': 0.992}]}]}],
#  'process_output_files': ['c:\\Users\\Lucas\\Desktop\\Content/f26060b4-b318-4ec6-b98f-539b45044abb.json']}

# %% [markdown]
# Look at that: it supposedly detects the words "I'm not sure if you can see the sound of the sound", and then essentially repeats the words "of the sound" ad nauseam. Does its training data somehow suggest that "you" is a valid interpretation of silence? Is the interpretation of "you" parametrically close to that of silence, so one results in the other? Is this, as some have suggested, the model 'complaining' to us?
#
# Let's see what happens if we use a stronger model, [whisper-medium](https://huggingface.co/openai/whisper-medium):

# %%
# .process a modem-sounds audio through the transcribe module with whisper-medium as the active model
pipeline_1.process(local_file_path='./test_files/modem_sounds.mp3',
                   modules={'transcribe': {'model': 'whisper-medium', 'params': {}}})
# Out:
# INFO: hydrated input modules: {'module_1': {'model': 'whisper-medium', 'params': {}}}
# INFO: symbolic_directory_path was not set by user - setting to default of /etc
# INFO: file_name was not set by user - setting to random file name: krixik_generated_file_name_kjunzkblsz.mp3
# INFO: expire_time was not set by user - setting to default of 1800 seconds
# INFO: wait_for_process is set to True.
# INFO: file will expire and be removed from you account in 1800 seconds, at Sat Jun  1 00:30:19 2024 UTC
# INFO: my_transcribe_pipeline file process and input processing started...
# INFO: metadata can be updated using the .update api.
# INFO: This process's request_id is: a13ed43a-da7a-8428-dbe2-36701d6de1e7
# INFO: File process and processing status:
# SUCCESS: module 1 (of 1) - module_1 processing complete.
# SUCCESS: pipeline process complete.
# SUCCESS: process output downloaded.
# {'status_code': 200,
#  'pipeline': 'my_transcribe_pipeline',
#  'request_id': '3359fa8e-2807-4415-b9f7-8da5da9b5598',
#  'file_id': '882e5b18-b891-4c3c-9ffc-83d5368d01fc',
#  'message': 'SUCCESS - output fetched for file_id 882e5b18-b891-4c3c-9ffc-83d5368d01fc.Output saved to location(s) listed in process_output_files.',
#  'warnings': [],
#  'process_output': [{'transcript': ' You You You You You',
#    'timestamped_transcript': [{'id': 0,
#      'start': 0.0,
#      'end': 0.84,
#      'text': ' You',
#      'no_speech_prob': 0.759978175163269,
#      'confidence': 0.032,
#      'words': [{'text': 'You',
#        'start': 0.0,
#        'end': 0.84,
#        'confidence': 0.032}]},
#     {'id': 1,
#      'start': 32.48,
#      'end': 32.5,
#      'text': ' You',
#      'no_speech_prob': 0.4594312906265259,
#      'confidence': 0.723,
#      'words': [{'text': 'You',
#        'start': 32.48,
#        'end': 32.5,
#        'confidence': 0.723}]},
#     {'id': 2,
#      'start': 60.0,
#      'end': 61.1,
#      'text': ' You',
#      'no_speech_prob': 0.43549519777297974,
#      'confidence': 0.77,
#      'words': [{'text': 'You',
#        'start': 60.0,
#        'end': 61.1,
#        'confidence': 0.77}]},
#     {'id': 3,
#      'start': 90.04,
#      'end': 90.68,
#      'text': ' You',
#      'no_speech_prob': 0.4500853419303894,
#      'confidence': 0.844,
#      'words': [{'text': 'You',
#        'start': 90.04,
#        'end': 90.68,
#        'confidence': 0.844}]},
#     {'id': 4,
#      'start': 122.48,
#      'end': 122.5,
#      'text': ' You',
#      'no_speech_prob': 0.49037936329841614,
#      'confidence': 0.962,
#      'words': [{'text': 'You',
#        'start': 122.48,
#        'end': 122.5,
#        'confidence': 0.962}]}]}],
#  'process_output_files': ['c:\\Users\\Lucas\\Desktop\\Content/882e5b18-b891-4c3c-9ffc-83d5368d01fc.json']}

# %% [markdown]
# The stronger model gives us a no less baffling transcription: the word "you" repeated five times. It detects the word at five random points of the audio. It is difficult not to note the similarity with the transcription of the silent audio above, although neither audio includes the word "you".
#
# The third model we'll leverage here, [whisper-base](https://huggingface.co/openai/whisper-base), falls between the previous two models:

# %%
# .process a modem-sounds audio through the transcribe module with whisper-base as the active model
pipeline_1.process(local_file_path='./test_files/modem_sounds.mp3',
                   modules={'transcribe': {'model': 'whisper-base', 'params': {}}})
# Out:
# INFO: hydrated input modules: {'module_1': {'model': 'whisper-base', 'params': {}}}
# INFO: symbolic_directory_path was not set by user - setting to default of /etc
# INFO: file_name was not set by user - setting to random file name: krixik_generated_file_name_aaxqkuksje.mp3
# INFO: expire_time was not set by user - setting to default of 1800 seconds
# INFO: wait_for_process is set to True.
# INFO: file will expire and be removed from you account in 1800 seconds, at Sat Jun  1 00:33:00 2024 UTC
# INFO: my_transcribe_pipeline file process and input processing started...
# INFO: metadata can be updated using the .update api.
# INFO: This process's request_id is: 081016b3-7321-5aa8-0ea3-2a67b0639570
# INFO: File process and processing status:
# SUCCESS: module 1 (of 1) - module_1 processing complete.
# SUCCESS: pipeline process complete.
# SUCCESS: process output downloaded.
# {'status_code': 200,
#  'pipeline': 'my_transcribe_pipeline',
#  'request_id': '1a5ae2c9-0bd9-4c39-b779-09b2d154b5c3',
#  'file_id': '46261d75-6c7d-4872-9ae0-95060739aa81',
#  'message': 'SUCCESS - output fetched for file_id 46261d75-6c7d-4872-9ae0-95060739aa81.Output saved to location(s) listed in process_output_files.',
#  'warnings': [],
#  'process_output': [{'transcript': " I'm not sure if I can get the right one. I'm not sure if I can get the right one. I'm not sure if I can get the right one. I'm not sure if I can get the right one. I'm not sure if I can get the right one. I'm not sure if I can get the right one. I'm not sure if I can get the right one. I'm not sure if I can get the right one. I'm not sure if I can get the right one.",
#    'timestamped_transcript': [{'id': 0,
#      'start': 60.14,
#      'end': 64.14,
#      'text': " I'm not sure if I can get the right one.",
#      'no_speech_prob': 0.6607950329780579,
#      'confidence': 0.118,
#      'words': [{'text': "I'm",
#        'start': 60.14,
#        'end': 60.72,
#        'confidence': 0.088},
#       {'text': 'not', 'start': 60.72, 'end': 60.74, 'confidence': 0.105},
#       {'text': 'sure', 'start': 60.74, 'end': 61.5, 'confidence': 0.129},
#       {'text': 'if', 'start': 61.5, 'end': 61.52, 'confidence': 0.237},
#       {'text': 'I', 'start': 61.52, 'end': 63.02, 'confidence': 0.32},
#       {'text': 'can', 'start': 63.02, 'end': 63.04, 'confidence': 0.267},
#       {'text': 'get', 'start': 63.04, 'end': 63.06, 'confidence': 0.127},
#       {'text': 'the', 'start': 63.06, 'end': 63.08, 'confidence': 0.11},
#       {'text': 'right', 'start': 63.08, 'end': 63.1, 'confidence': 0.031},
#       {'text': 'one.', 'start': 63.1, 'end': 64.14, 'confidence': 0.065}]},
#     {'id': 1,
#      'start': 66.5,
#      'end': 70.06,
#      'text': " I'm not sure if I can get the right one.",
#      'no_speech_prob': 0.6607950329780579,
#      'confidence': 0.584,
#      'words': [{'text': "I'm",
#        'start': 66.5,
#        'end': 68.58,
#        'confidence': 0.218},
#       {'text': 'not', 'start': 68.58, 'end': 68.6, 'confidence': 0.315},
#       {'text': 'sure', 'start': 68.6, 'end': 68.62, 'confidence': 0.794},
#       {'text': 'if', 'start': 68.62, 'end': 68.64, 'confidence': 0.598},
#       {'text': 'I', 'start': 68.64, 'end': 68.66, 'confidence': 0.804},
#       {'text': 'can', 'start': 68.66, 'end': 68.68, 'confidence': 0.817},
#       {'text': 'get', 'start': 68.68, 'end': 68.7, 'confidence': 0.928},
#       {'text': 'the', 'start': 68.7, 'end': 68.84, 'confidence': 0.744},
#       {'text': 'right', 'start': 68.84, 'end': 68.86, 'confidence': 0.873},
#       {'text': 'one.', 'start': 68.86, 'end': 70.06, 'confidence': 0.961}]},
#     {'id': 2,
#      'start': 73.5,
#      'end': 76.6,
#      'text': " I'm not sure if I can get the right one.",
#      'no_speech_prob': 0.6607950329780579,
#      'confidence': 0.836,
#      'words': [{'text': "I'm",
#        'start': 73.5,
#        'end': 75.04,
#        'confidence': 0.516},
#       {'text': 'not', 'start': 75.04, 'end': 75.06, 'confidence': 0.877},
#       {'text': 'sure', 'start': 75.06, 'end': 75.08, 'confidence': 0.954},
#       {'text': 'if', 'start': 75.08, 'end': 75.1, 'confidence': 0.851},
#       {'text': 'I', 'start': 75.1, 'end': 75.66, 'confidence': 0.952},
#       {'text': 'can', 'start': 75.66, 'end': 75.68, 'confidence': 0.949},
#       {'text': 'get', 'start': 75.68, 'end': 75.7, 'confidence': 0.975},
#       {'text': 'the', 'start': 75.7, 'end': 76.48, 'confidence': 0.922},
#       {'text': 'right', 'start': 76.48, 'end': 76.5, 'confidence': 0.931},
#       {'text': 'one.', 'start': 76.5, 'end': 76.6, 'confidence': 0.976}]},
#     {'id': 3,
#      'start': 78.8,
#      'end': 83.42,
#      'text': " I'm not sure if I can get the right one.",
#      'no_speech_prob': 0.6607950329780579,
#      'confidence': 0.873,
#      'words': [{'text': "I'm",
#        'start': 78.8,
#        'end': 79.22,
#        'confidence': 0.599},
#       {'text': 'not', 'start': 79.22, 'end': 79.34, 'confidence': 0.943},
#       {'text': 'sure', 'start': 79.34, 'end': 79.56, 'confidence': 0.955},
#       {'text': 'if', 'start': 79.56, 'end': 81.78, 'confidence': 0.886},
#       {'text': 'I', 'start': 81.78, 'end': 81.94, 'confidence': 0.957},
#       {'text': 'can', 'start': 81.94, 'end': 81.96, 'confidence': 0.968},
#       {'text': 'get', 'start': 81.96, 'end': 82.02, 'confidence': 0.976},
#       {'text': 'the', 'start': 82.02, 'end': 83.36, 'confidence': 0.938},
#       {'text': 'right', 'start': 83.36, 'end': 83.4, 'confidence': 0.949},
#       {'text': 'one.', 'start': 83.4, 'end': 83.42, 'confidence': 0.971}]},
#     {'id': 4,
#      'start': 85.0,
#      'end': 88.3,
#      'text': " I'm not sure if I can get the right one.",
#      'no_speech_prob': 0.7389898896217346,
#      'confidence': 0.923,
#      'words': [{'text': "I'm",
#        'start': 85.0,
#        'end': 88.04,
#        'confidence': 0.752},
#       {'text': 'not', 'start': 88.04, 'end': 88.06, 'confidence': 0.985},
#       {'text': 'sure', 'start': 88.06, 'end': 88.08, 'confidence': 0.963},
#       {'text': 'if', 'start': 88.08, 'end': 88.1, 'confidence': 0.894},
#       {'text': 'I', 'start': 88.1, 'end': 88.2, 'confidence': 0.977},
#       {'text': 'can', 'start': 88.2, 'end': 88.22, 'confidence': 0.986},
#       {'text': 'get', 'start': 88.22, 'end': 88.24, 'confidence': 0.984},
#       {'text': 'the', 'start': 88.24, 'end': 88.26, 'confidence': 0.956},
#       {'text': 'right', 'start': 88.26, 'end': 88.28, 'confidence': 0.989},
#       {'text': 'one.', 'start': 88.28, 'end': 88.3, 'confidence': 0.969}]},
#     {'id': 5,
#      'start': 91.5,
#      'end': 94.02,
#      'text': " I'm not sure if I can get the right one.",
#      'no_speech_prob': 0.7389898896217346,
#      'confidence': 0.946,
#      'words': [{'text': "I'm",
#        'start': 91.5,
#        'end': 93.12,
#        'confidence': 0.836},
#       {'text': 'not', 'start': 93.12, 'end': 93.14, 'confidence': 0.983},
#       {'text': 'sure', 'start': 93.14, 'end': 93.42, 'confidence': 0.975},
#       {'text': 'if', 'start': 93.42, 'end': 93.44, 'confidence': 0.922},
#       {'text': 'I', 'start': 93.44, 'end': 93.68, 'confidence': 0.977},
#       {'text': 'can', 'start': 93.68, 'end': 93.7, 'confidence': 0.986},
#       {'text': 'get', 'start': 93.7, 'end': 93.96, 'confidence': 0.987},
#       {'text': 'the', 'start': 93.96, 'end': 93.98, 'confidence': 0.958},
#       {'text': 'right', 'start': 93.98, 'end': 94.0, 'confidence': 0.988},
#       {'text': 'one.', 'start': 94.0, 'end': 94.02, 'confidence': 0.974}]},
#     {'id': 6,
#      'start': 98.5,
#      'end': 101.08,
#      'text': " I'm not sure if I can get the right one.",
#      'no_speech_prob': 0.7389898896217346,
#      'confidence': 0.945,
#      'words': [{'text': "I'm",
#        'start': 98.5,
#        'end': 100.28,
#        'confidence': 0.823},
#       {'text': 'not', 'start': 100.28, 'end': 100.3, 'confidence': 0.989},
#       {'text': 'sure', 'start': 100.3, 'end': 100.32, 'confidence': 0.979},
#       {'text': 'if', 'start': 100.32, 'end': 100.34, 'confidence': 0.934},
#       {'text': 'I', 'start': 100.34, 'end': 100.36, 'confidence': 0.977},
#       {'text': 'can', 'start': 100.36, 'end': 100.38, 'confidence': 0.989},
#       {'text': 'get', 'start': 100.38, 'end': 100.4, 'confidence': 0.987},
#       {'text': 'the', 'start': 100.4, 'end': 101.04, 'confidence': 0.959},
#       {'text': 'right', 'start': 101.04, 'end': 101.06, 'confidence': 0.986},
#       {'text': 'one.', 'start': 101.06, 'end': 101.08, 'confidence': 0.972}]},
#     {'id': 7,
#      'start': 105.56,
#      'end': 108.52,
#      'text': " I'm not sure if I can get the right one.",
#      'no_speech_prob': 0.7389898896217346,
#      'confidence': 0.907,
#      'words': [{'text': "I'm",
#        'start': 105.56,
#        'end': 107.04,
#        'confidence': 0.666},
#       {'text': 'not', 'start': 107.04, 'end': 107.28, 'confidence': 0.991},
#       {'text': 'sure', 'start': 107.28, 'end': 107.76, 'confidence': 0.973},
#       {'text': 'if', 'start': 107.76, 'end': 108.12, 'confidence': 0.924},
#       {'text': 'I', 'start': 108.12, 'end': 108.14, 'confidence': 0.974},
#       {'text': 'can', 'start': 108.14, 'end': 108.16, 'confidence': 0.99},
#       {'text': 'get', 'start': 108.16, 'end': 108.18, 'confidence': 0.985},
#       {'text': 'the', 'start': 108.18, 'end': 108.2, 'confidence': 0.96},
#       {'text': 'right', 'start': 108.2, 'end': 108.5, 'confidence': 0.983},
#       {'text': 'one.', 'start': 108.5, 'end': 108.52, 'confidence': 0.969}]},
#     {'id': 8,
#      'start': 112.0,
#      'end': 114.0,
#      'text': " I'm not sure if I can get the right one.",
#      'no_speech_prob': 0.7625329494476318,
#      'confidence': 0.89,
#      'words': [{'text': "I'm",
#        'start': 112.0,
#        'end': 112.02,
#        'confidence': 0.63},
#       {'text': 'not', 'start': 112.02, 'end': 112.04, 'confidence': 0.978},
#       {'text': 'sure', 'start': 112.04, 'end': 112.06, 'confidence': 0.936},
#       {'text': 'if', 'start': 112.06, 'end': 112.44, 'confidence': 0.875},
#       {'text': 'I', 'start': 112.44, 'end': 112.46, 'confidence': 0.975},
#       {'text': 'can', 'start': 112.46, 'end': 113.38, 'confidence': 0.986},
#       {'text': 'get', 'start': 113.38, 'end': 113.94, 'confidence': 0.985},
#       {'text': 'the', 'start': 113.94, 'end': 113.96, 'confidence': 0.958},
#       {'text': 'right', 'start': 113.96, 'end': 113.98, 'confidence': 0.99},
#       {'text': 'one.',
#        'start': 113.98,
#        'end': 114.0,
#        'confidence': 0.976}]}]}],
#  'process_output_files': ['c:\\Users\\Lucas\\Desktop\\Content/46261d75-6c7d-4872-9ae0-95060739aa81.json']}

# %% [markdown]
# As you can see, this transcription is closer to what [whisper-tiny](https://huggingface.co/openai/whisper-tiny) produced: the repetition of a phrase that is nowhere to be found in the audio. In this case, the repeated phrase is "I'm not sure if I can get the right one."
#
# ### Conclusion
#
# This hallucination comparison gives us a peek at how these models function, how they've been built, and how they can fail. Much has been written about this topic elsewhere, so please feel free to explore; we will not delve into detail here. I offer the following thought instead: [whisper-tiny](https://huggingface.co/openai/whisper-tiny) was no less likely to hallucinate than [whisper-medium](https://huggingface.co/openai/whisper-medium), a heavier, more powerful, more expensive model. In what other ways is the smaller model just as good as its heftier siblings?
#
# Transcription hallucinations can be interesting, fun, and sometimes even a little spooky (for instance, try transcribing an audio file that holds Cradle of Filth's cover of the Misfits' *Death Comes Ripping*—why don't you [create a Krixik pipeline](https://krixik-docs.readthedocs.io/en/latest/examples/single_module_pipelines/single_transcribe/) and give it a shot?). This technology is evolving at extraordinary speed, and hallucinations like these these may soon largely become a thing of the past.
#
# That said, how close they'll come to being "perfect" is another matter altogether... although to be fair, the human auditory/interpretative system doesn't always score perfect marks either.
